# %%
import json
import pandas as pd
from pandas import DataFrame

results_path = 'results.json'  # JSON 파일 경로

# JSON 파일 가져오기
with open(results_path, 'r', encoding='utf-8') as f:
    results = json.load(f)

data = DataFrame(results)
print(data)
# Out:
#                                                         1  \
# 상품명               *○○ I** 1+1 롱암 스마트폰 자바라 거치대 침대 책상 휴대폰걸이
# 리뷰           자바라 프레임의 무게가 가벼워 건들거리는 담점이 있지만 저렴하고 가성비가 좋아요
# 감정분석결과  {'document': {'sentiment': 'positive', 'confid...
#
#                                                         2  \
# 상품명                                      K_○○ ** 핏2 / S**
# 리뷰      생각보다 활용할수있는 메뉴가 제한적이고 디스플레이 변경도 정해진대로만 가능하지만 운...
# 감정분석결과  {'document': {'sentiment': 'positive', 'confid...
#
#                                                         3  \
# 상품명                                     MS**01 멀티 충전기 스탠드
# 리뷰      누가 쓴 거 처럼 스크레치가 있네요 다 뚫려 있는 디자인이라 옆으로 다 빠져나와서 ...
# 감정분석결과  {'document': {'sentiment': 'negative', 'confid...
#
#                                                         4  \
# 상품명                              머** 1+1 스마트폰 휴대폰 태블릿 거치대
# 리뷰                                가볍고 심플한 디자인이라 아주 실용적이예요
# 감정분석결과  {'document': {'sentiment': 'positive', 'confid...
#
# ...
